# %%
import altair as alt
import pandas as pd

# %%
df = pd.read_csv('completo.csv')
df
# Out:
#               Data  Hora UTC  PRECIPITAÇÃO TOTAL | HORÁRIO (mm)  \
# 0       2019/01/01  0000 UTC                                0.0
# 1       2019/01/01  0100 UTC                                0.0
# 2       2019/01/01  0200 UTC                                0.0
# 3       2019/01/01  0300 UTC                                0.0
# 4       2019/01/01  0400 UTC                                0.0
# ...            ...       ...                                ...
# 266971  2019/12/31  1900 UTC                                0.6
# 266972  2019/12/31  2000 UTC                                1.2
# 266973  2019/12/31  2100 UTC                                0.0
# 266974  2019/12/31  2200 UTC                                1.2
# 266975  2019/12/31  2300 UTC                                1.6
#
#         PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO | HORARIA (mB)  \
# 0                                                  1010.2
# 1                                                  1010.4
# ...

# %%
alt.Chart(df).mark_point().encode(
    alt.X('PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB):Q'),
    alt.Y('RADIACAO GLOBAL (W/m²):Q')
)
# Out:
# alt.Chart(...)
